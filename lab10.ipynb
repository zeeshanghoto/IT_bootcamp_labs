# %%
import numpy as np
import pandas as pd

# %%
test_input_and=np.array([[0,0],[0,1],[1,0],[1,1]])
correct_outputs_and=[False,False,False,True]

weight1_and=1.0
weight2_and=1.0
bias_and=2.0

# %%
test_input_or=np.array([[0,0],[0,1],[1,0],[1,1]])
correct_outputs_or=[False,True,True,True]

weight1_or=2.0
weight1_or=2.0

bias_or=1.0

# %%
test_input_not=np.array([[0],[1]])
correct_outputs_not=[True,False]

weight1_not=1.0
weight1_not=2.0

bias_not=0.0

# %%
linear_combination=np.multiply(weight1_and,test_input_and[:,:1])+np.multiply(weight2_and,test_input_and[:,1:2])+bias_not

# %%
linear_combination
# Out:
# array([[0.],
#        [1.],
#        [1.],
#        [2.]])

# %%
def train_Model_Logic(weight1,weight2,test_inputs,correct_outputs,bias,name="And"):

    outputs=[]
    linear_combination=np.multiply(weight1,test_inputs[:,:1])+np.multiply(weight2,test_inputs[:,1:2])+bias
    output=(linear_combination>=0)

    num_wrong=np.array_equal(output,correct_outputs)
    out={'Input1':test_inputs[:,:1].ravel().T,'Input2':test_inputs[:,1:2].ravel().T,'Correct Output':correct_outputs,'linear_combination':linear_combination.T.ravel(),'output':output.T.ravel()}
    frame=pd.DataFrame(out)

    if not num_wrong:

        print("Successfully build {0} logic gate".format(name))
    else:
        print("Something went wrong")

    return frame

# %%
output_and=train_Model_Logic(weight1_and,weight2_and,test_input_and,correct_outputs_and,bias_and)

output_and
# Out:
# Successfully build And logic gate
#    Input1  Input2  Correct Output  linear_combination  output
# 0       0       0           False                 2.0    True
# 1       0       1           False                 3.0    True
# 2       1       0           False                 3.0    True
# 3       1       1            True                 4.0    True

# %%
output_or=train_Model_Logic(weight1_or,weight2_and,test_input_or,correct_outputs_or,bias_and,name='OR')

output_or
# Out:
# Successfully build OR logic gate
#    Input1  Input2  Correct Output  linear_combination  output
# 0       0       0           False                 2.0    True
# 1       0       1            True                 3.0    True
# 2       1       0            True                 4.0    True
# 3       1       1            True                 5.0    True

# %%
output_not=train_Model_Logic(weight1_not,weight2_not,test_input_not,correct_outputs_not,bias_not,name="NOT")
output_not
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-0d736251b1dd> in <cell line: 1>()
# ----> 1 output_not=train_Model_Logic(weight1_not,weight2_not,test_input_not,correct_outputs_not,bias_not,name="NOT")
#       2 output_not
#
# NameError: name 'weight2_not' is not defined
